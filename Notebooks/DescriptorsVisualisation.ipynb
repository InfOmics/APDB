# %%
import os
import pandas as pd
import numpy as np
import scipy as sc
import random
import pickle 

import sklearn
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# suppress all warnings
import warnings
warnings.filterwarnings('ignore') 

SEED = 42
random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
np.random.seed(SEED)

# %%
# path to read
path_read = '../Flask/psql_db/Tables'
# path to save
path_save = '../Flask/pollutants_db_app/static/img'

# %% [markdown]
# #### FP bits space

# %%
# load fingerprint data
fingerprint_data = pd.read_csv(path_read + '/FingerprintsTable.csv')
print(fingerprint_data.index, "\n", fingerprint_data.columns)
# Out:
# Int64Index([  8680, 143127,  10870,  69848,  12993, 164514,  86240,  13129,
#              67884,   6278,
#             ...
#              26042,  24193,  23963,  23964,  23989,  23990,  23992,  23993,
#              23994,  23995],
#            dtype='int64', length=1826)
#  Index(['FP1', 'FP2', 'FP3', 'FP4', 'FP5', 'FP6', 'FP7', 'FP8', 'FP9', 'FP10',
#        ...
#        'APC2D10_I_I', 'APC2D10_I_B', 'APC2D10_I_Si', 'APC2D10_I_X',
#        'APC2D10_B_B', 'APC2D10_B_Si', 'APC2D10_B_X', 'APC2D10_Si_Si',
#        'APC2D10_Si_X', 'APC2D10_X_X'],
#       dtype='object', length=16092)

# %%
# read FPB object
filename = '../Preprocessed_data/fp_bits.obj'
filehandler = open(filename, 'rb') 
Fpb_obj = pickle.load(filehandler)
Fpb_obj
# Out:
# {'annotation': {'samples': Int64Index([   8680,  143127,   10870,   69848,   12993,  164514,   86240,
#                 13129,   67884,    6278,
#               ...
#                  1117,    1119,   24682, 4685067,   14778,   24841,   14781,
#                 11430,   26042,   24193],
#              dtype='int64', length=1750),
#   'features': Index(['FP1', 'FP2', 'FP3', 'FP4', 'FP5', 'FP6', 'FP7', 'FP8', 'FP9', 'FP10',
#          ...
#          'AD2D714', 'AD2D715', 'AD2D726', 'AD2D729', 'AD2D735', 'AD2D760',
#          'AD2D765', 'AD2D766', 'AD2D770', 'AD2D780'],
#         dtype='object', length=5218)},
#  'tfidf': {'tfidf_transformer': TfidfTransformer(),
#   'tfidf_data': <1750x5218 sparse matrix of type '<class 'numpy.float64'>'
#   	with 467820 stored elements in Compressed Sparse Row format>},
#  'lsa': {'lsa_data': array([[ 4.46150378e-01,  4.65599796e-01, -2.30471042e-01, ...,
#            1.78108040e-02, -4.14571861e-03,  3.34084720e-02],
#          [ 7.61418679e-01, -2.97931919e-01, -2.92913529e-01, ...,
#            1.42308671e-04, -9.40650231e-03,  1.28397737e-02],
#          [ 4.51208175e-01,  4.74807693e-01, -2.37553373e-01, ...,
#            1.75571899e-02, -6.93623439e-03,  1.47783681e-02],
#          ...,
#          [ 1.10628745e-01,  4.62585697e-02,  2.17856269e-01, ...,
#           -1.58662159e-02,  1.36538402e-01,  8.80338746e-02],
#          [ 3.85456583e-02,  2.39565132e-02,  6.61475516e-02, ...,
#            8.57162322e-02,  5.93244730e-03, -9.05575687e-02],
#          [ 2.68065313e-02,  2.11110412e-02,  5.01424483e-03, ...,
#            1.52926931e-01,  4.42718881e-02, -5.93372067e-02]]),
#   'features_components': {'Component 0': ['KRFP3706',
#     'KRFP3692',
#     'FP511',
#     'ExtFP836',
#     'FP502',
#     'FP501',
#     'FP149',
#     'FP619',
#     'ExtFP763',
#     'FP618'],
#    'Component 1': ['ExtFP933',
#     'FP81',
#     'ExtFP79',
#     'FP162',
#     'ExtFP703',
#     'PubchemFP371',
#     'FP183',
#     'PubchemFP470',
#     'PubchemFP520',
#     'PubchemFP552'],
#    'Component 2': ['GraphFP245',
#     'PubchemFP286',
#     'AD2D3',
#     'PubchemFP352',
#     'GraphFP243',
#     'GraphFP367',
#     'KRFP3788',
#     'KRFP3956',
#     'ExtFP119',
#     'KRFP4331'],
#    'Component 3': ['SubFP5',
#     'MACCSFP76',
#     'FP589',
#     'MACCSFP99',
#     'KRFP2986',
#     'KRFP3440',
#     'FP678',
#     'ExtFP21',
#     'FP843',
#     'FP1015'],
#    'Component 4': ['KRFP14',
#     'EStateFP13',
#     'KRFP1',
#     'MACCSFP138',
#     'MACCSFP153',
#     'MACCSFP109',
#     'KRFP3369',
#     'FP298',
#     'MACCSFP66',
#     'MACCSFP141'],
#    'Component 5': ['MACCSFP161',
#     'PubchemFP14',
#     'KRFP4080',
#     'GraphFP970',
#     'MACCSFP122',
#     'MACCSFP148',
#     'PubchemFP285',
#     'AD2D2',
#     'MACCSFP156',
#     'MACCSFP158'],
#    'Component 6': ['FP464',
#     'PubchemFP385',
#     'PubchemFP186',
#     'FP536',
#     'ExtFP22',
#     'EStateFP18',
#     'ExtFP879',
#     'PubchemFP193',
#     'MACCSFP145',
#     'PubchemFP185'],
#    'Component 7': ['MACCSFP134',
#     'MACCSFP107',
#     'AD2D12',
#     'EStateFP54',
#     'MACCSFP103',
#     'PubchemFP37',
#     'KRFP2259',
#     'KRFP3821',
#     'PubchemFP294',
#     'AD2D7'],
#    'Component 8': ['FP283',
#     'PubchemFP406',
#     'GraphFP787',
#     'MACCSFP139',
#     'PubchemFP308',
#     'FP746',
#     'EStateFP34',
#     'KRFP1148',
#     'KRFP2949',
#     'ExtFP914'],
#    'Component 9': ['FP326',
#     'SubFP12',
#     'MACCSFP139',
#     'PubchemFP308',
#     'PubchemFP406',
#     'ExtFP728',
#     'GraphFP787',
#     'EStateFP34',
#     'KRFP1148',
#     'KRFP2949'],
#    'Component 10': ['KRFP3659',
#     'KRFP3369',
#     'KRFP3660',
#     'KRFP3336',
#     'MACCSFP66',
#     'KRFP3657',
#     'PubchemFP334',
#     'SubFP4',
#     'PubchemFP711',
#     'PubchemFP335'],
#    'Component 11': ['EStateFP19',
#     'KRFP1154',
#     'PubchemFP711',
#     'PubchemFP334',
#     'SubFP4',
#     'KRFP1156',
#     'KRFP3657',
#     'KRFP3336',
#     'KRFP1160',
#     'KRFP3058'],
#    'Component 12': ['GraphFP190',
#     'PubchemFP401',
#     'PubchemFP455',
#     'MACCSFP24',
#     'MACCSFP63',
#     'PubchemFP423',
#     'KRFP4117',
#     'MACCSFP70',
#     'KRFP2380',
#     'MACCSFP71'],
#    'Component 13': ['KRFP1160',
#     'PubchemFP334',
#     'SubFP4',
#     'KRFP1156',
#     'KRFP3336',
#     'EStateFP19',
#     'KRFP1154',
#     'PubchemFP711',
#     'KRFP3657',
#     'KRFP1173'],
#    'Component 14': ['SubFP48',
#     'PubchemFP436',
#     'KRFP3268',
#     'KRFP189',
#     'SubFP49',
#     'PubchemFP448',
#     'PubchemFP432',
#     'ExtFP654',
#     'KRFP3643',
#     'MACCSFP72'],
#    'Component 15': ['EStateFP19',
#     'KRFP1154',
#     'KRFP1156',
#     'PubchemFP334',
#     'SubFP4',
#     'KRFP3336',
#     'PubchemFP711',
#     'KRFP3657',
#     'KRFP1160',
#     'KRFP3749'],
#    'Component 16': ['KRFP1160',
#     'PubchemFP334',
#     'SubFP4',
#     'KRFP3336',
#     'KRFP1156',
#     'PubchemFP711',
#     'KRFP3657',
#     'EStateFP19',
#     'KRFP1154',
#     'KRFP1173'],
#    'Component 17': ['AD2D156',
#     'KRFP3749',
#     'AD2D141',
#     'SubFP8',
#     'PubchemFP436',
#     'GraphFP892',
#     'ExtFP573',
#     'MACCSFP96',
#     'PubchemFP143',
#     'PubchemFP448'],
#    'Component 18': ['EStateFP8',
#     'MACCSFP34',
#     'KRFP3593',
#     'KRFP3058',
#     'KRFP138',
#     'KRFP3150',
#     'ExtFP351',
#     'FP992',
#     'FP86',
#     'SubFP303'],
#    'Component 19': ['EStateFP8',
#     'MACCSFP34',
#     'KRFP138',
#     'SubFP84',
#     'SubFP297',
#     'SubFP299',
#     'KRFP1147',
#     'KRFP339',
#     'MACCSFP146',
#     'FP644'],
#    'Component 20': ['MACCSFP126',
#     'ExtFP886',
#     'MACCSFP149',
#     'KRFP382',
#     'ExtFP773',
#     'FP930',
#     'FP866',
#     'KRFP354',
#     'AD2D102',
#     'ExtFP258'],
#    'Component 21': ['ExtFP947',
#     'FP546',
#     'ExtFP989',
#     'MACCSFP96',
#     'PubchemFP143',
#     'ExtFP441',
#     'FP344',
#     'FP76',
#     'ExtFP824',
#     'FP708'],
#    'Component 22': ['KRFP92',
#     'KRFP307',
#     'KRFP342',
#     'MACCSFP74',
#     'KRFP14',
#     'KRFP299',
#     'ExtFP137',
#     'MACCSFP141',
#     'FP88',
#     'KRFP91'],
#    'Component 23': ['FP118',
#     'FP80',
#     'ExtFP45',
#     'ExtFP72',
#     'FP663',
#     'ExtFP80',
#     'FP524',
#     'ExtFP415',
#     'FP64',
#     'ExtFP785'],
#    'Component 24': ['KRFP3058',
#     'MACCSFP150',
#     'MACCSFP165',
#     'ExtFP1010',
#     'ExtFP1014',
#     'KRFP3150',
#     'MACCSFP96',
#     'PubchemFP143',
#     'FP88',
#     'KRFP3593'],
#    'Component 25': ['KRFP92',
#     'PubchemFP366',
#     'MACCSFP74',
#     'KRFP14',
#     'PubchemFP448',
#     'KRFP307',
#     'KRFP189',
#     'PubchemFP436',
#     'ExtFP654',
#     'KRFP2667'],
#    'Component 26': ['GraphFP745',
#     'FP745',
#     'MACCSFP88',
#     'PubchemFP33',
#     'ExtFP23',
#     'KRFP4843',
#     'MACCSFP93',
#     'MACCSFP124',
#     'MACCSFP102',
#     'KRFP2667'],
#    'Component 27': ['MACCSFP42',
#     'PubchemFP23',
#     'KRFP4032',
#     'EStateFP38',
#     'KRFP2260',
#     'PubchemFP287',
#     'SubFP9',
#     'AD2D6',
#     'AD2D135',
#     'GraphFP946'],
#    'Component 28': ['MACCSFP17',
#     'PubchemFP417',
#     'SubFP6',
#     'KRFP2976',
#     'ExtFP415',
#     'ExtFP582',
#     'FP524',
#     'PubchemFP427',
#     'EStateFP15',
#     'KRFP3225'],
#    'Component 29': ['MACCSFP17',
#     'PubchemFP417',
#     'SubFP6',
#     'KRFP2976',
#     'PubchemFP427',
#     'EStateFP15',
#     'KRFP3225',
#     'FP598',
#     'ExtFP582',
#     'FP617'],
#    'Component 30': ['KRFP189',
#     'PubchemFP448',
#     'ExtFP654',
#     'SubFP48',
#     'PubchemFP436',
#     'SubFP88',
#     'PubchemFP346',
#     'FP87',
#     'EStateFP11',
#     'PubchemFP366'],
#    'Component 31': ['KRFP92',
#     'MACCSFP74',
#     'KRFP1564',
#     'KRFP307',
#     'ExtFP355',
#     'FP907',
#     'KRFP14',
#     'KRFP342',
#     'EStateFP13',
#     'KRFP1'],
#    'Component 32': ['KRFP189',
#     'ExtFP654',
#     'SubFP48',
#     'PubchemFP448',
#     'PubchemFP436',
#     'PubchemFP346',
#     'EStateFP11',
#     'PubchemFP366',
#     'GraphFP245',
#     'FP87'],
#    'Component 33': ['GraphFP745',
#     'MACCSFP88',
#     'PubchemFP33',
#     'FP745',
#     'KRFP4843',
#     'ExtFP23',
#     'KRFP3593',
#     'KRFP3150',
#     'MACCSFP73',
#     'PubchemFP293'],
#    'Component 34': ['ExtFP160',
#     'ExtFP686',
#     'FP816',
#     'FP394',
#     'ExtFP153',
#     'GraphFP156',
#     'ExtFP698',
#     'GraphFP929',
#     'ExtFP762',
#     'MACCSFP20'],
#    'Component 35': ['KRFP3593',
#     'KRFP3150',
#     'KRFP3268',
#     'FP415',
#     'KRFP3643',
#     'MACCSFP124',
#     'MACCSFP102',
#     'KRFP214',
#     'FP410',
#     'MACCSFP130'],
#    'Component 36': ['SubFP303',
#     'KRFP3010',
#     'FP819',
#     'FP394',
#     'MACCSFP124',
#     'FP86',
#     'ExtFP621',
#     'ExtFP724',
#     'MACCSFP102',
#     'FP471'],
#    'Component 37': ['FP1006',
#     'ExtFP739',
#     'FP1011',
#     'ExtFP634',
#     'FP822',
#     'ExtFP571',
#     'KRFP1564',
#     'FP233',
#     'ExtFP52',
#     'ExtFP597'],
#    'Component 38': ['PubchemFP329',
#     'KRFP3223',
#     'EStateFP70',
#     'MACCSFP46',
#     'PubchemFP43',
#     'PubchemFP297',
#     'KRFP1150',
#     'KRFP2950',
#     'AD2D8',
#     'GraphFP652'],
#    'Component 39': ['ExtFP355',
#     'FP335',
#     'MACCSFP20',
#     'PubchemFP28',
#     'ExtFP63',
#     'FP87',
#     'ExtFP897',
#     'GraphFP915',
#     'PubchemFP313',
#     'AD2D32'],
#    'Component 40': ['KRFP3268',
#     'SubFP16',
#     'FP447',
#     'KRFP3593',
#     'GraphFP725',
#     'KRFP3643',
#     'KRFP3150',
#     'GraphFP227',
#     'ExtFP638',
#     'FP481'],
#    'Component 41': ['MACCSFP114',
#     'KRFP466',
#     'KRFP3660',
#     'KRFP7',
#     'PubchemFP710',
#     'KRFP91',
#     'GraphFP745',
#     'MACCSFP88',
#     'PubchemFP33',
#     'PubchemFP594'],
#    'Component 42': ['KRFP3149',
#     'PubchemFP144',
#     'MACCSFP96',
#     'PubchemFP143',
#     'PubchemFP860',
#     'PubchemFP839',
#     'KRFP92',
#     'ExtFP104',
#     'FP173',
#     'PubchemFP3'],
#    'Component 43': ['KRFP3593',
#     'KRFP3150',
#     'KRFP214',
#     'FP173',
#     'FP170',
#     'ExtFP104',
#     'FP651',
#     'PubchemFP178',
#     'PubchemFP179',
#     'ExtFP113'],
#    'Component 44': ['FP803',
#     'ExtFP726',
#     'ExtFP584',
#     'ExtFP114',
#     'FP375',
#     'FP147',
#     'FP142',
#     'ExtFP245',
#     'FP146',
#     'ExtFP410'],
#    'Component 45': ['EStateFP26',
#     'MACCSFP41',
#     'PubchemFP419',
#     'SubFP133',
#     'KRFP2977',
#     'ExtFP27',
#     'KRFP1153',
#     'MACCSFP114',
#     'KRFP466',
#     'KRFP91'],
#    'Component 46': ['PubchemFP3',
#     'PubchemFP12',
#     'AD2D703',
#     'KRFP349',
#     'FP720',
#     'ExtFP282',
#     'KRFP3150',
#     'AD2D625',
#     'KRFP2',
#     'KRFP214'],
#    'Component 47': ['GraphFP303',
#     'GraphFP723',
#     'GraphFP660',
#     'GraphFP641',
#     'GraphFP689',
#     'GraphFP308',
#     'GraphFP122',
#     'GraphFP563',
#     'GraphFP455',
#     'ExtFP126'],
#    'Component 48': ['KRFP307',
#     'KRFP342',
#     'MACCSFP48',
#     'MACCSFP102',
#     'MACCSFP106',
#     'MACCSFP130',
#     'GraphFP964',
#     'ExtFP354',
#     'FP147',
#     'GraphFP321'],
#    'Component 49': ['FP297',
#     'FP455',
#     'PubchemFP563',
#     'ExtFP170',
#     'ExtFP19',
#     'ExtFP457',
#     'FP965',
#     'PubchemFP610',
#     'GraphFP670',
#     'KRFP3408'],
#    'Component 50': ['EStateFP8',
#     'MACCSFP34',
#     'MACCSFP50',
#     'KRFP7',
#     'PubchemFP144',
#     'ExtFP98',
#     'KRFP3149',
#     'FP571',
#     'FP847',
#     'ExtFP963'],
#    'Component 51': ['KRFP307',
#     'KRFP342',
#     'KRFP92',
#     'MACCSFP74',
#     'KRFP344',
#     'MACCSFP118',
#     'MACCSFP147',
#     'KRFP341',
#     'EStateFP26',
#     'MACCSFP41'],
#    'Component 52': ['MACCSFP140',
#     'PubchemFP20',
#     'ExtFP354',
#     'MACCSFP146',
#     'FP759',
#     'MACCSFP86',
#     'FP75',
#     'MACCSFP124',
#     'FP472',
#     'MACCSFP16'],
#    'Component 53': ['ExtFP153',
#     'ExtFP487',
#     'ExtFP612',
#     'ExtFP495',
#     'FP637',
#     'FP677',
#     'FP126',
#     'ExtFP850',
#     'FP759',
#     'FP302'],
#    'Component 54': ['GraphFP195',
#     'PubchemFP639',
#     'GraphFP227',
#     'MACCSFP89',
#     'AD2D258',
#     'FP965',
#     'PubchemFP610',
#     'FP297',
#     'PubchemFP563',
#     'ExtFP562'],
#    'Component 55': ['KRFP307',
#     'ExtFP136',
#     'ExtFP163',
#     'FP957',
#     'KRFP3529',
#     'KRFP92',
#     'ExtFP267',
#     'PubchemFP776',
#     'KRFP3593',
#     'FP834'],
#    'Component 56': ['ExtFP267',
#     'MACCSFP89',
#     'AD2D258',
#     'ExtFP442',
#     'PubchemFP639',
#     'GraphFP195',
#     'ExtFP163',
#     'FP957',
#     'KRFP3529',
#     'MACCSFP136'],
#    'Component 57': ['EStateFP26',
#     'MACCSFP41',
#     'PubchemFP419',
#     'SubFP133',
#     'KRFP2977',
#     'KRFP1153',
#     'FP140',
#     'PubchemFP429',
#     'ExtFP460',
#     'EStateFP15'],
#    'Component 58': ['KRFP91',
#     'ExtFP422',
#     'EStateFP26',
#     'MACCSFP41',
#     'PubchemFP419',
#     'SubFP133',
#     'KRFP2977',
#     'ExtFP460',
#     'KRFP1153',
#     'FP236'],
#    'Component 59': ['KRFP91',
#     'KRFP3149',
#     'KRFP7',
#     'SubFP22',
#     'KRFP3660',
#     'MACCSFP114',
#     'KRFP466',
#     'PubchemFP144',
#     'EStateFP14',
#     'ExtFP837'],
#    'Component 60': ['MACCSFP60',
#     'AD2D25',
#     'ExtFP422',
#     'PubchemFP459',
#     'MACCSFP55',
#     'MACCSFP58',
#     'GraphFP196',
#     'KRFP3596',
#     'KRFP494',
#     'ExtFP858'],
#    'Component 61': ['PubchemFP144',
#     'ExtFP631',
#     'KRFP3149',
#     'MACCSFP66',
#     'MACCSFP96',
#     'PubchemFP143',
#     'KRFP3369',
#     'AD2D136',
#     'GraphFP471',
#     'PubchemFP360'],
#    'Component 62': ['EStateFP14',
#     'MACCSFP110',
#     'GraphFP309',
#     'MACCSFP117',
#     'AD2D92',
#     'MACCSFP89',
#     'AD2D258',
#     'GraphFP205',
#     'MACCSFP140',
#     'PubchemFP20'],
#    'Component 63': ['ExtFP456',
#     'KRFP92',
#     'EStateFP46',
#     'MACCSFP29',
#     'PubchemFP30',
#     'PubchemFP314',
#     'AD2D26',
#     'FP196',
#     'GraphFP205',
#     'PubchemFP411'],
#    'Component 64': ['KRFP1155',
#     'KRFP307',
#     'KRFP214',
#     'KRFP1159',
#     'EStateFP14',
#     'KRFP1169',
#     'KRFP3659',
#     'KRFP342',
#     'ExtFP289',
#     'KRFP3369'],
#    'Component 65': ['MACCSFP50',
#     'EStateFP14',
#     'KRFP2',
#     'FP38',
#     'MACCSFP78',
#     'KRFP3013',
#     'FP975',
#     'SubFP22',
#     'PubchemFP39',
#     'EStateFP16'],
#    'Component 66': ['SubFP22',
#     'ExtFP837',
#     'SubFP298',
#     'FP1006',
#     'KRFP3408',
#     'ExtFP118',
#     'KRFP214',
#     'KRFP349',
#     'MACCSFP49',
#     'SubFP296'],
#    'Component 67': ['SubFP298',
#     'SubFP22',
#     'EStateFP14',
#     'ExtFP837',
#     'KRFP126',
#     'KRFP92',
#     'MACCSFP78',
#     'KRFP3013',
#     'KRFP338',
#     'KRFP2'],
#    'Component 68': ['SubFP22',
#     'ExtFP837',
#     'SubFP298',
#     'AD2D136',
#     'ExtFP631',
#     'GraphFP471',
#     'PubchemFP360',
#     'KRFP3881',
#     'FP603',
#     'AD2D141'],
#    'Component 69': ['KRFP92',
#     'KRFP1155',
#     'KRFP1159',
#     'FP571',
#     'ExtFP267',
#     'KRFP342',
#     'KRFP307',
#     'MACCSFP114',
#     'KRFP466',
#     'ExtFP415'],
#    'Component 70': ['KRFP1159',
#     'SubFP298',
#     'KRFP1155',
#     'SubFP22',
#     'PubchemFP343',
#     'ExtFP837',
#     'ExtFP267',
#     'KRFP1169',
#     'MACCSFP93',
#     'KRFP126'],
#    'Component 71': ['KRFP350',
#     'KRFP347',
#     'KRFP354',
#     'PubchemFP335',
#     'SubFP3',
#     'KRFP1173',
#     'KRFP3375',
#     'KRFP348',
#     'KRFP349',
#     'KRFP3369'],
#    'Component 72': ['SubFP22',
#     'ExtFP837',
#     'KRFP2',
#     'FP1006',
#     'PubchemFP712',
#     'MACCSFP52',
#     'PubchemFP300',
#     'AD2D13',
#     'SubFP298',
#     'GraphFP966'],
#    'Component 73': ['KRFP1155',
#     'KRFP1159',
#     'KRFP1169',
#     'KRFP3660',
#     'KRFP4811',
#     'PubchemFP462',
#     'PubchemFP537',
#     'MACCSFP136',
#     'PubchemFP710',
#     'ExtFP643'],
#    'Component 74': ['EStateFP14',
#     'MACCSFP136',
#     'KRFP3408',
#     'MACCSFP95',
#     'ExtFP465',
#     'ExtFP704',
#     'PubchemFP566',
#     'GraphFP366',
#     'ExtFP368',
#     'FP124'],
#    'Component 75': ['KRFP1155',
#     'KRFP1159',
#     'MACCSFP50',
#     'KRFP1169',
#     'FP414',
#     'PubchemFP430',
#     'ExtFP747',
#     'ExtFP962',
#     'KRFP92',
#     'KRFP307'],
#    'Component 76': ['KRFP1155',
#     'KRFP1159',
#     'KRFP1169',
#     'KRFP214',
#     'PubchemFP337',
#     'KRFP3360',
#     'MACCSFP66',
#     'KRFP3369',
#     'SubFP15',
#     'KRFP1157'],
#    'Component 77': ['KRFP1173',
#     'KRFP497',
#     'FP864',
#     'ExtFP460',
#     'ExtFP60',
#     'ExtFP112',
#     'ExtFP95',
#     'ExtFP865',
#     'FP416',
#     'FP951'],
#    'Component 78': ['PubchemFP337',
#     'KRFP3360',
#     'KRFP1173',
#     'FP416',
#     'ExtFP806',
#     'ExtFP213',
#     'FP503',
#     'ExtFP60',
#     'ExtFP865',
#     'KRFP1160'],
#    'Component 79': ['KRFP2',
#     'KRFP1263',
#     'KRFP2682',
#     'FP414',
#     'FP77',
#     'ExtFP591',
#     'KRFP299',
#     'FP885',
#     'FP629',
#     'ExtFP530'],
#    'Component 80': ['KRFP1173',
#     'ExtFP409',
#     'ExtFP391',
#     'PubchemFP144',
#     'KRFP3722',
#     'FP207',
#     'ExtFP602',
#     'FP907',
#     'GraphFP554',
#     'KRFP344'],
#    'Component 81': ['KRFP7',
#     'KRFP382',
#     'MACCSFP114',
#     'KRFP466',
#     'MACCSFP127',
#     'MACCSFP143',
#     'SubFP22',
#     'ExtFP837',
#     'ExtFP513',
#     'KRFP341'],
#    'Component 82': ['KRFP91',
#     'FP124',
#     'PubchemFP12',
#     'PubchemFP3',
#     'ExtFP431',
#     'KRFP214',
#     'MACCSFP86',
#     'KRFP1155',
#     'KRFP1159',
#     'AD2D703'],
#    'Component 83': ['KRFP214',
#     'KRFP382',
#     'KRFP354',
#     'KRFP362',
#     'MACCSFP114',
#     'KRFP466',
#     'ExtFP130',
#     'ExtFP645',
#     'KRFP350',
#     'ExtFP133'],
#    'Component 84': ['KRFP7',
#     'KRFP382',
#     'KRFP2',
#     'EStateFP14',
#     'KRFP1173',
#     'KRFP92',
#     'FP458',
#     'FP967',
#     'MACCSFP151',
#     'PubchemFP299'],
#    'Component 85': ['KRFP91',
#     'MACCSFP50',
#     'KRFP299',
#     'ExtFP460',
#     'ExtFP33',
#     'KRFP3394',
#     'KRFP2682',
#     'PubchemFP430',
#     'ExtFP60',
#     'ExtFP98'],
#    'Component 86': ['KRFP7',
#     'KRFP382',
#     'KRFP92',
#     'KRFP362',
#     'FP447',
#     'KRFP214',
#     'FP78',
#     'KRFP344',
#     'MACCSFP74',
#     'AD2D319'],
#    'Component 87': ['KRFP2',
#     'SubFP22',
#     'EStateFP49',
#     'PubchemFP712',
#     'ExtFP837',
#     'FP309',
#     'ExtFP921',
#     'ExtFP876',
#     'GraphFP886',
#     'PubchemFP421'],
#    'Component 88': ['KRFP2595',
#     'GraphFP252',
#     'PubchemFP686',
#     'MACCSFP108',
#     'ExtFP302',
#     'PubchemFP681',
#     'EStateFP8',
#     'MACCSFP34',
#     'KRFP4821',
#     'FP799'],
#    'Component 89': ['KRFP138',
#     'KRFP2',
#     'ExtFP60',
#     'MACCSFP93',
#     'FP22',
#     'FP506',
#     'PubchemFP516',
#     'KRFP2667',
#     'FP39',
#     'EStateFP11'],
#    'Component 90': ['KRFP2',
#     'PubchemFP712',
#     'KRFP92',
#     'KRFP382',
#     'MACCSFP74',
#     'ExtFP807',
#     'EStateFP49',
#     'PubchemFP421',
#     'MACCSFP95',
#     'GraphFP540'],
#    'Component 91': ['KRFP7',
#     'KRFP1564',
#     'PubchemFP3',
#     'SubFP22',
#     'PubchemFP337',
#     'ExtFP837',
#     'KRFP3394',
#     'SubFP15',
#     'KRFP1157',
#     'SubFP279'],
#    'Component 92': ['KRFP91',
#     'KRFP299',
#     'ExtFP577',
#     'ExtFP844',
#     'ExtFP133',
#     'KRFP1173',
#     'FP121',
#     'FP328',
#     'ExtFP218',
#     'FP236'],
#    'Component 93': ['SubFP22',
#     'ExtFP837',
#     'FP1006',
#     'SubFP298',
#     'GraphFP363',
#     'MACCSFP109',
#     'FP528',
#     'FP782',
#     'KRFP4829',
#     'FP644'],
#    'Component 94': ['KRFP7',
#     'MACCSFP106',
#     'FP188',
#     'FP504',
#     'KRFP1151',
#     'FP309',
#     'ExtFP378',
#     'FP967',
#     'SubFP143',
#     'KRFP3884'],
#    'Component 95': ['KRFP14',
#     'KRFP1159',
#     'KRFP1155',
#     'ExtFP621',
#     'FP86',
#     'MACCSFP79',
#     'KRFP92',
#     'KRFP1169',
#     'SubFP8',
#     'KRFP2'],
#    'Component 96': ['EStateFP14',
#     'ExtFP717',
#     'FP967',
#     'SubFP7',
#     'FP124',
#     'FP17',
#     'MACCSFP69',
#     'ExtFP465',
#     'MACCSFP114',
#     'KRFP466'],
#    'Component 97': ['KRFP7',
#     'AD2D234',
#     'AD2D219',
#     'GraphFP704',
#     'AD2D214',
#     'MACCSFP136',
#     'KRFP2595',
#     'ExtFP547',
#     'PubchemFP529',
#     'KRFP4472'],
#    'Component 98': ['KRFP91',
#     'KRFP344',
#     'FP167',
#     'ExtFP465',
#     'KRFP346',
#     'KRFP3722',
#     'SubFP143',
#     'GraphFP554',
#     'FP207',
#     'ExtFP409'],
#    'Component 99': ['KRFP2',
#     'SubFP279',
#     'SubFP280',
#     'PubchemFP115',
#     'PubchemFP712',
#     'PubchemFP118',
#     'MACCSFP141',
#     'KRFP362',
#     'MACCSFP50',
#     'KRFP354'],
#    'Component 100': ['KRFP2595',
#     'FP394',
#     'MACCSFP114',
#     'KRFP466',
#     'GraphFP156',
#     'ExtFP698',
#     'ExtFP98',
#     'AD2D234',
#     'AD2D219',
#     'GraphFP704'],
#    'Component 101': ['EStateFP10',
#     'PubchemFP428',
#     'FP973',
#     'ExtFP848',
#     'KRFP7',
#     'KRFP566',
#     'FP187',
#     'FP185',
#     'ExtFP965',
#     'ExtFP941'],
#    'Component 102': ['PubchemFP115',
#     'SubFP279',
#     'SubFP280',
#     'PubchemFP118',
#     'AD2D336',
#     'GraphFP252',
#     'SubFP276',
#     'MACCSFP136',
#     'SubFP143',
#     'PubchemFP681'],
#    'Component 103': ['KRFP7',
#     'KRFP382',
#     'FP967',
#     'ExtFP465',
#     'MACCSFP115',
#     'PubchemFP3',
#     'KRFP214',
#     'MACCSFP114',
#     'KRFP466',
#     'EStateFP14'],
#    'Component 104': ['EStateFP14',
#     'FP86',
#     'KRFP2',
#     'SubFP7',
#     'FP967',
#     'ExtFP60',
#     'FP78',
#     'FP447',
#     'ExtFP858',
#     'ExtFP967'],
#    'Component 105': ['KRFP1151',
#     'ExtFP800',
#     'FP188',
#     'FP642',
#     'FP504',
#     'FP156',
#     'FP607',
#     'ExtFP378',
#     'KRFP91',
#     'ExtFP615'],
#    'Component 106': ['FP967',
#     'EStateFP14',
#     'SubFP7',
#     'ExtFP465',
#     'FP124',
#     'ExtFP717',
#     'MACCSFP166',
#     'MACCSFP15',
#     'ExtFP752',
#     'FP42'],
#    'Component 107': ['SubFP7',
#     'KRFP2',
#     'FP967',
#     'ExtFP465',
#     'KRFP362',
#     'KRFP91',
#     'ExtFP717',
#     'FP124',
#     'MACCSFP114',
#     'KRFP466'],
#    'Component 108': ['KRFP19',
#     'KRFP18',
#     'FP249',
#     'KRFP91',
#     'KRFP362',
#     'FP22',
#     'KRFP214',
#     'MACCSFP116',
#     'FP416',
#     'MACCSFP114'],
#    'Component 109': ['ExtFP394',
#     'GraphFP252',
#     'SubFP143',
#     'PubchemFP681',
#     'FP612',
#     'EStateFP13',
#     'KRFP1',
#     'FP752',
#     'GraphFP353',
#     'EStateFP10'],
#    'Component 110': ['KRFP7',
#     'KRFP2',
#     'PubchemFP3',
#     'SubFP143',
#     'PubchemFP712',
#     'PubchemFP337',
#     'MACCSFP15',
#     'PubchemFP12',
#     'ExtFP391',
#     'FP86'],
#    'Component 111': ['SubFP292',
#     'ExtFP325',
#     'KRFP2595',
#     'SubFP14',
#     'KRFP17',
#     'GraphFP961',
#     'MACCSFP27',
#     'PubchemFP46',
#     'KRFP4074',
#     'FP898'],
#    'Component 112': ['KRFP7',
#     'KRFP497',
#     'GraphFP885',
#     'FP43',
#     'AD2D705',
#     'KRFP1155',
#     'ExtFP726',
#     'ExtFP153',
#     'KRFP1592',
#     'AD2D627'],
#    'Component 113': ['SubFP143',
#     'PubchemFP115',
#     'SubFP279',
#     'SubFP280',
#     'FP691',
#     'KRFP2',
#     'MACCSFP115',
#     'AD2D414',
#     'ExtFP530',
#     'KRFP138'],
#    'Component 114': ['KRFP7',
#     'MACCSFP50',
#     'KRFP1263',
#     'KRFP382',
#     'KRFP498',
#     'EStateFP16',
#     'ExtFP21',
#     'FP678',
#     'ExtFP277',
#     'ExtFP156'],
#    'Component 115': ['MACCSFP10',
#     'KRFP382',
#     'PubchemFP52',
#     'MACCSFP102',
#     'MACCSFP124',
#     'PubchemFP860',
#     'KRFP91',
#     'FP238',
#     'KRFP362',
#     'PubchemFP839'],
#    'Component 116': ['GraphFP156',
#     'SubFP279',
#     'SubFP280',
#     'PubchemFP115',
#     'FP394',
#     'KRFP18',
#     'MACCSFP105',
#     'ExtFP698',
#     'SubFP292',
#     'GraphFP961'],
#    'Component 117': ['SubFP292',
#     'ExtFP547',
#     'FP124',
#     'KRFP4472',
#     'MACCSFP16',
#     'ExtFP756',
#     'GraphFP961',
#     'MACCSFP27',
#     'PubchemFP46',
#     'KRFP4074'],
#    'Component 118': ['KRFP299',
#     'GraphFP961',
#     'MACCSFP27',
#     'PubchemFP46',
#     'KRFP4074',
#     'SubFP292',
#     'KRFP14',
#     'MACCSFP15',
#     'KRFP354',
#     'FP602'],
#    'Component 119': ['KRFP91',
#     'KRFP3375',
#     'KRFP20',
#     'KRFP98',
#     'FP486',
#     'KRFP444',
#     'ExtFP938',
#     'ExtFP344',
#     'KRFP216',
#     'FP703']}},
#  'metric': {'similarity_matrix': array([[ 1.        ,  0.32145306,  0.98386429, ...,  0.00981803,
#            0.00198125, -0.00153972],
#          [ 0.32145306,  1.        ,  0.2968389 , ...,  0.0110891 ,
#            0.00852895,  0.01863717],
#          [ 0.98386429,  0.2968389 ,  1.        , ...,  0.01098356,
#            0.00414366, -0.00245019],
#          ...,
#          [ 0.00981803,  0.0110891 ,  0.01098356, ...,  1.        ,
#            0.15982661,  0.03038078],
#          [ 0.00198125,  0.00852895,  0.00414366, ...,  0.15982661,
#            1.        ,  0.50546997],
#          [-0.00153972,  0.01863717, -0.00245019, ...,  0.03038078,
#            0.50546997,  1.        ]]),
#   'pvalue_matrix': array([[0.512, 1.001, 0.002, ..., 1.001, 1.001, 1.001],
#          [1.001, 0.183, 1.001, ..., 1.001, 1.001, 1.001],
#          [0.002, 1.001, 0.445, ..., 1.001, 1.001, 1.001],
#          ...,
#          [1.001, 1.001, 1.001, ..., 0.247, 1.001, 1.001],
#          [1.001, 1.001, 1.001, ..., 1.001, 0.54 , 1.001],
#          [1.001, 1.001, 1.001, ..., 1.001, 1.001, 0.366]])},
#  'net': {'network':          Source  Target  Similarity  Pvalue  -Log10Pvalue
#   1          8680   10870    0.983864   0.002       2.69897
#   35         8680    8404    0.808318   0.002       2.69897
#   48         8680  187815    0.638885   0.002       2.69897
#   49         8680  520522    0.623915   0.002       2.69897
#   58         8680   13415    0.619416   0.002       2.69897
#   ...         ...     ...         ...     ...           ...
#   1530327   10340   11430    0.998023   0.002       2.69897
#   1530330    1117    1119    0.945078   0.002       2.69897
#   1530331    1117   24682    0.970619   0.002       2.69897
#   1530339    1119   24682    0.987565   0.002       2.69897
#   1530363   14778   26042    0.705540   0.002       2.69897
#
#   [75978 rows x 5 columns],
#   'graph': <networkx.classes.graph.Graph at 0x19862fa1f60>}}

# %%
# get fingerprints bits by subsetting preprocessed columns 
fingerprint_bits = fingerprint_data.loc[:,Fpb_obj['annotation']['features']]
print(fingerprint_bits.columns)
# Out:
# Index(['FP1', 'FP2', 'FP3', 'FP4', 'FP5', 'FP6', 'FP7', 'FP8', 'FP9', 'FP10',
#        ...
#        'AD2D714', 'AD2D715', 'AD2D726', 'AD2D729', 'AD2D735', 'AD2D760',
#        'AD2D765', 'AD2D766', 'AD2D770', 'AD2D780'],
#       dtype='object', length=5218)

# %%
# print idf values of fingeprints bits 
df_idf_fpb = pd.DataFrame(Fpb_obj['tfidf']['tfidf_transformer'].idf_, index=fingerprint_bits.columns, columns=["idf_weights"]) 
# sort ascending 
df_idf_fpb.sort_values(by=['idf_weights'])
# Out:
#             idf_weights
# GraphFP742     1.009756
# FP742          1.009756
# FP743          1.012066
# GraphFP743     1.012066
# SubFP307       1.013222
# ...                 ...
# KRFP1449       7.774795
# KRFP2870       7.774795
# KRFP2877       7.774795
# KRFP4498       7.774795
# KRFP3380       7.774795
#
# [5218 rows x 1 columns]

# %% [markdown]
# ##### FP bits classes:
# | Fingerprint | Class | Number | Code |
# | --- | --- | --- | --- |
# | CDK fingerprint | Fingerprinter | 1024 | FP
# | CDK extended fingerprint | ExtendedFingerprinter | 1024 | ExtFP
# | CDK graph only fingerprint | GraphOnlyFingerprinter | 1024 | GraphFP
# | Estate fingerprint | EStateFingerprinter | 79	| EStateFP
# | MACCS fingerprint	| MACCSFingerprinter |166 |	MACCSFP
# | Pubchem fingerprint | PubchemFingerprinter | 881 | PubchemFP
# | Substructure fingerprint | SubstructureFingerprinter | 307 | SubFP
# | Klekota-Roth fingerprint | KlekotaRothFingerprinter | 4860 | KRFP
# | 2D atom pairs | AtomPairs2DFingerprinter | 780 | AD2D

# %%
# subset fingerprints bits classes
fpb_classes = ['FP', 'ExtFP', 'GraphFP', 'EStateFP', 'MACCSFP', 'PubchemFP', 'SubFP', 'KRFP', 'AD2D']

# %%
# get idf weights of fingerprints bits classes 
fpb_classes_df = pd.DataFrame()
for i in fpb_classes:
    df = df_idf_fpb[df_idf_fpb.index.str.startswith(i)]
    df.insert(0, 'Fingerprint', df.index)
    df.insert(2, 'Class', i)
    # sort weights
    df = df.sort_values(by=['idf_weights'])
    fpb_classes_df = pd.concat([fpb_classes_df, df])
fpb_classes_df
# Out:
#         Fingerprint  idf_weights Class
# FP742         FP742     1.009756    FP
# FP743         FP743     1.012066    FP
# FP972         FP972     1.035459    FP
# FP638         FP638     1.143452    FP
# FP921         FP921     1.159400    FP
# ...             ...          ...   ...
# AD2D458     AD2D458     7.774795  AD2D
# AD2D454     AD2D454     7.774795  AD2D
# AD2D261     AD2D261     7.774795  AD2D
# AD2D500     AD2D500     7.774795  AD2D
# AD2D497     AD2D497     7.774795  AD2D
#
# [5218 rows x 3 columns]

# %%
# plot the fingerprints bits distribution
fig = px.line_polar(fpb_classes_df, r='idf_weights', theta='Fingerprint', 
                    width=450, height=400, line_close=False, color='Class', title="Fingerprints Bits - Weights Distribution (IDF)",
                    color_discrete_sequence=px.colors.sequential.Plasma_r, )
# configuration
config = {'modeBarButtonsToRemove': ['zoom'],'displaylogo': False}
fig.update_polars(angularaxis_showticklabels=False)
fig.update_layout(font_size=12, title_x=0.5, title_font_size=14)
# save figure
fig.write_html(path_save + '/fingerprints_bits_idf.html', config=config)
fig.show(config=config)

# %% [markdown]
# #### FP counts space

# %%
# read FPC object
filename = '../Preprocessed_data/fp_counts.obj'
filehandler = open(filename, 'rb') 
Fpc_obj = pickle.load(filehandler)
Fpc_obj
# Out:
# {'annotation': {'samples': Int64Index([   8680,  143127,   10870,   69848,   12993,  164514,   86240,
#                 13129,   67884,    6278,
#               ...
#                  1117,    1119,   24682, 4685067,   14778,   24841,   14781,
#                 11430,   26042,   24193],
#              dtype='int64', length=1750),
#   'features': Index(['SubFPC1', 'SubFPC2', 'SubFPC3', 'SubFPC4', 'SubFPC5', 'SubFPC6',
#          'SubFPC7', 'SubFPC8', 'SubFPC9', 'SubFPC10',
#          ...
#          'APC2D10_C_X', 'APC2D10_N_N', 'APC2D10_O_O', 'APC2D10_O_F',
#          'APC2D10_O_X', 'APC2D10_Cl_Cl', 'APC2D10_Cl_X', 'APC2D10_Br_Br',
#          'APC2D10_Br_X', 'APC2D10_X_X'],
#         dtype='object', length=1515)},
#  'tfidf': {'tfidf_transformer': TfidfTransformer(),
#   'tfidf_data': <1750x1515 sparse matrix of type '<class 'numpy.float64'>'
#   	with 76585 stored elements in Compressed Sparse Row format>},
#  'lsa': {'lsa_data': array([[ 8.12594735e-01,  3.60701844e-01, -1.29693415e-02, ...,
#           -9.78689333e-02, -3.07306474e-02,  3.94343634e-02],
#          [ 8.66342802e-01, -2.68506293e-01,  2.76738087e-01, ...,
#            2.33018707e-02,  6.93602820e-04,  2.95283514e-02],
#          [ 8.27690236e-01,  3.55163736e-01, -1.18646421e-02, ...,
#           -8.38098205e-02, -1.85535885e-02,  2.60144923e-02],
#          ...,
#          [ 8.20517649e-02,  5.73270101e-02, -1.92788304e-01, ...,
#           -2.39406992e-02, -8.86203273e-03,  5.95672052e-03],
#          [ 4.09162069e-02,  2.78780347e-02, -1.25064551e-01, ...,
#           -3.12188034e-02,  1.44678869e-01, -8.68445865e-02],
#          [ 7.47539745e-03,  8.03703890e-03, -1.01763845e-02, ...,
#            1.03690470e-01, -6.35129668e-02, -5.91198228e-02]]),
#   'features_components': {'Component 0': ['SubFPC300',
#     'SubFPC301',
#     'APC2D2_C_C',
#     'SubFPC307',
#     'APC2D3_C_C',
#     'APC2D1_C_C',
#     'KRFPC2975',
#     'APC2D4_C_C',
#     'KRFPC3640',
#     'KRFPC3224'],
#    'Component 1': ['SubFPC274',
#     'APC2D2_C_C',
#     'APC2D3_C_C',
#     'APC2D4_C_C',
#     'APC2D1_C_C',
#     'SubFPC307',
#     'APC2D5_C_C',
#     'APC2D4_C_O',
#     'APC2D3_C_O',
#     'APC2D5_C_O'],
#    'Component 2': ['KRFPC3706',
#     'KRFPC3719',
#     'KRFPC3722',
#     'KRFPC3712',
#     'KRFPC3692',
#     'APC2D4_C_C',
#     'APC2D5_C_C',
#     'APC2D6_C_C',
#     'APC2D3_C_C',
#     'KRFPC3660'],
#    'Component 3': ['KRFPC347',
#     'KRFPC346',
#     'KRFPC348',
#     'APC2D8_C_C',
#     'APC2D4_C_O',
#     'APC2D3_C_O',
#     'APC2D7_C_C',
#     'KRFPC344',
#     'APC2D9_C_C',
#     'APC2D10_C_C'],
#    'Component 4': ['APC2D3_C_X',
#     'APC2D3_C_Cl',
#     'APC2D2_C_X',
#     'APC2D2_C_Cl',
#     'APC2D4_C_X',
#     'APC2D4_C_Cl',
#     'APC2D1_C_X',
#     'KRFPC3821',
#     'KRFPC2259',
#     'APC2D1_C_Cl'],
#    'Component 5': ['KRFPC3659',
#     'KRFPC3660',
#     'APC2D3_C_O',
#     'APC2D4_C_O',
#     'KRFPC3706',
#     'APC2D2_C_O',
#     'APC2D5_C_O',
#     'KRFPC3692',
#     'APC2D1_C_O',
#     'KRFPC4331'],
#    'Component 6': ['APC2D2_C_N',
#     'APC2D1_C_N',
#     'APC2D3_C_N',
#     'APC2D4_C_N',
#     'KRFPC4080',
#     'KRFPC3882',
#     'SubFPC296',
#     'APC2D1_N_O',
#     'KRFPC2380',
#     'SubFPC274'],
#    'Component 7': ['SubFPC137',
#     'SubFPC287',
#     'KRFPC3440',
#     'APC2D3_C_O',
#     'APC2D1_C_C',
#     'APC2D4_C_O',
#     'SubFPC2',
#     'APC2D2_C_C',
#     'KRFPC346',
#     'KRFPC344'],
#    'Component 8': ['SubFPC274',
#     'KRFPC3722',
#     'KRFPC3719',
#     'APC2D2_C_O',
#     'SubFPC295',
#     'APC2D1_C_O',
#     'SubFPC307',
#     'KRFPC3712',
#     'KRFPC1148',
#     'KRFPC2949'],
#    'Component 9': ['APC2D2_X_X',
#     'KRFPC3749',
#     'KRFPC3722',
#     'APC2D1_C_X',
#     'APC2D2_Cl_X',
#     'KRFPC3440',
#     'SubFPC8',
#     'KRFPC2259',
#     'KRFPC3821',
#     'KRFPC2986'],
#    'Component 10': ['APC2D2_X_X',
#     'KRFPC3749',
#     'SubFPC274',
#     'APC2D1_C_X',
#     'APC2D2_Cl_X',
#     'SubFPC296',
#     'SubFPC8',
#     'APC2D1_N_O',
#     'KRFPC2380',
#     'APC2D2_F_X'],
#    'Component 11': ['SubFPC296',
#     'KRFPC3722',
#     'APC2D2_O_O',
#     'KRFPC4331',
#     'SubFPC297',
#     'SubFPC299',
#     'APC2D1_N_O',
#     'KRFPC1147',
#     'KRFPC3719',
#     'SubFPC298'],
#    'Component 12': ['KRFPC3455',
#     'KRFPC3025',
#     'KRFPC3671',
#     'SubFPC295',
#     'SubFPC88',
#     'KRFPC1193',
#     'KRFPC4695',
#     'KRFPC3328',
#     'KRFPC3654',
#     'KRFPC3701'],
#    'Component 13': ['KRFPC3882',
#     'KRFPC3926',
#     'KRFPC3773',
#     'KRFPC4331',
#     'KRFPC3750',
#     'APC2D4_C_C',
#     'SubFPC296',
#     'KRFPC669',
#     'SubFPC295',
#     'APC2D5_C_C'],
#    'Component 14': ['KRFPC1148',
#     'KRFPC2949',
#     'APC2D2_C_O',
#     'SubFPC12',
#     'KRFPC3440',
#     'APC2D3_O_O',
#     'APC2D6_C_C',
#     'KRFPC4331',
#     'KRFPC3455',
#     'KRFPC3640'],
#    'Component 15': ['KRFPC3773',
#     'KRFPC297',
#     'KRFPC3882',
#     'KRFPC3750',
#     'KRFPC341',
#     'KRFPC3926',
#     'SubFPC12',
#     'APC2D3_C_C',
#     'KRFPC494',
#     'SubFPC13'],
#    'Component 16': ['APC2D2_F_X',
#     'KRFPC4032',
#     'KRFPC2260',
#     'APC2D1_C_F',
#     'SubFPC9',
#     'APC2D2_C_F',
#     'APC2D2_F_F',
#     'APC2D3_F_X',
#     'APC2D3_F_F',
#     'APC2D2_X_X'],
#    'Component 17': ['SubFPC137',
#     'SubFPC287',
#     'KRFPC3659',
#     'APC2D8_C_C',
#     'APC2D7_C_C',
#     'APC2D9_C_C',
#     'APC2D10_C_C',
#     'SubFPC296',
#     'KRFPC647',
#     'KRFPC3692'],
#    'Component 18': ['APC2D1_C_S',
#     'KRFPC4843',
#     'APC2D3_C_S',
#     'KRFPC3440',
#     'KRFPC2667',
#     'APC2D1_O_S',
#     'SubFPC295',
#     'KRFPC3706',
#     'SubFPC2',
#     'KRFPC297'],
#    'Component 19': ['KRFPC3659',
#     'KRFPC3657',
#     'KRFPC348',
#     'KRFPC347',
#     'KRFPC3058',
#     'KRFPC3369',
#     'KRFPC3660',
#     'APC2D9_C_C',
#     'APC2D7_C_O',
#     'APC2D6_C_O'],
#    'Component 20': ['APC2D1_C_S',
#     'KRFPC4843',
#     'APC2D3_C_S',
#     'APC2D2_C_S',
#     'KRFPC4019',
#     'APC2D4_C_S',
#     'APC2D1_O_S',
#     'KRFPC3744',
#     'KRFPC3722',
#     'SubFPC96'],
#    'Component 21': ['APC2D1_N_O',
#     'APC2D6_C_Cl',
#     'APC2D6_C_X',
#     'KRFPC348',
#     'KRFPC347',
#     'KRFPC2380',
#     'APC2D5_C_Cl',
#     'APC2D5_C_X',
#     'KRFPC3455',
#     'KRFPC346'],
#    'Component 22': ['APC2D5_C_O',
#     'KRFPC444',
#     'APC2D6_C_X',
#     'APC2D6_C_Cl',
#     'APC2D7_C_O',
#     'SubFPC184',
#     'SubFPC296',
#     'APC2D8_C_O',
#     'APC2D7_C_C',
#     'KRFPC3223'],
#    'Component 23': ['KRFPC3455',
#     'KRFPC189',
#     'APC2D3_C_X',
#     'SubFPC48',
#     'APC2D2_C_X',
#     'APC2D3_C_Cl',
#     'SubFPC49',
#     'KRFPC3268',
#     'KRFPC3025',
#     'APC2D2_C_Cl'],
#    'Component 24': ['KRFPC3225',
#     'KRFPC2976',
#     'SubFPC6',
#     'SubFPC288',
#     'KRFPC2975',
#     'KRFPC1151',
#     'APC2D3_C_N',
#     'SubFPC295',
#     'APC2D3_O_O',
#     'KRFPC348'],
#    'Component 25': ['KRFPC3223',
#     'KRFPC1150',
#     'KRFPC2950',
#     'APC2D1_C_Br',
#     'KRFPC3225',
#     'SubFPC10',
#     'SubFPC6',
#     'KRFPC2976',
#     'KRFPC4331',
#     'APC2D2_C_Br'],
#    'Component 26': ['SubFPC279',
#     'SubFPC280',
#     'KRFPC3225',
#     'KRFPC2976',
#     'SubFPC6',
#     'APC2D1_N_O',
#     'KRFPC2380',
#     'KRFPC1150',
#     'KRFPC2950',
#     'APC2D1_C_Br'],
#    'Component 27': ['KRFPC3223',
#     'KRFPC1150',
#     'KRFPC2950',
#     'APC2D1_C_Br',
#     'SubFPC10',
#     'SubFPC279',
#     'SubFPC280',
#     'APC2D4_C_C',
#     'KRFPC3408',
#     'KRFPC348'],
#    'Component 28': ['SubFPC279',
#     'SubFPC280',
#     'APC2D1_O_Si',
#     'KRFPC4331',
#     'APC2D1_O_S',
#     'APC2D2_C_Si',
#     'APC2D2_O_O',
#     'APC2D3_C_Si',
#     'SubFPC137',
#     'APC2D3_C_N'],
#    'Component 29': ['KRFPC4080',
#     'SubFPC133',
#     'KRFPC2977',
#     'KRFPC3013',
#     'KRFPC3682',
#     'KRFPC1146',
#     'KRFPC4331',
#     'KRFPC3660',
#     'KRFPC189',
#     'APC2D7_C_C'],
#    'Component 30': ['KRFPC4331',
#     'APC2D1_O_S',
#     'APC2D2_O_O',
#     'KRFPC298',
#     'KRFPC299',
#     'APC2D9_C_C',
#     'SubFPC3',
#     'KRFPC3682',
#     'APC2D10_C_C',
#     'KRFPC14'],
#    'Component 31': ['KRFPC189',
#     'SubFPC48',
#     'SubFPC88',
#     'KRFPC3610',
#     'SubFPC182',
#     'KRFPC3159',
#     'APC2D6_C_O',
#     'APC2D7_C_O',
#     'APC2D3_C_Si',
#     'APC2D1_O_Si'],
#    'Component 32': ['APC2D1_O_Si',
#     'APC2D3_C_Si',
#     'APC2D2_C_Si',
#     'APC2D2_C_O',
#     'KRFPC3660',
#     'KRFPC4080',
#     'APC2D1_C_Si',
#     'SubFPC275',
#     'KRFPC3706',
#     'SubFPC184'],
#    'Component 33': ['APC2D1_O_S',
#     'KRFPC4331',
#     'SubFPC275',
#     'SubFPC184',
#     'APC2D2_C_N',
#     'APC2D1_N_O',
#     'SubFPC137',
#     'KRFPC3408',
#     'KRFPC189',
#     'SubFPC181'],
#    'Component 34': ['APC2D2_N_O',
#     'KRFPC3942',
#     'APC2D1_O_Si',
#     'KRFPC4237',
#     'APC2D1_N_O',
#     'KRFPC2264',
#     'APC2D2_C_Si',
#     'APC2D3_C_O',
#     'KRFPC3648',
#     'KRFPC3926'],
#    'Component 35': ['APC2D1_O_S',
#     'KRFPC4080',
#     'APC2D6_C_O',
#     'APC2D7_C_O',
#     'APC2D8_C_O',
#     'KRFPC3882',
#     'KRFPC3640',
#     'KRFPC3369',
#     'KRFPC3408',
#     'SubFPC298'],
#    'Component 36': ['APC2D6_O_O',
#     'SubFPC133',
#     'KRFPC2977',
#     'SubFPC302',
#     'KRFPC299',
#     'KRFPC444',
#     'KRFPC1153',
#     'SubFPC3',
#     'KRFPC14',
#     'KRFPC4080'],
#    'Component 37': ['APC2D1_O_P',
#     'APC2D6_O_O',
#     'KRFPC1263',
#     'KRFPC3408',
#     'APC2D4_C_O',
#     'APC2D2_C_O',
#     'APC2D1_C_N',
#     'KRFPC2682',
#     'APC2D2_O_O',
#     'APC2D3_O_O'],
#    'Component 38': ['KRFPC3682',
#     'APC2D3_X_X',
#     'SubFPC133',
#     'KRFPC2977',
#     'KRFPC3382',
#     'APC2D3_C_O',
#     'APC2D3_Cl_X',
#     'SubFPC303',
#     'SubFPC22',
#     'SubFPC296'],
#    'Component 39': ['APC2D3_X_X',
#     'SubFPC68',
#     'APC2D2_C_X',
#     'APC2D3_Cl_X',
#     'APC2D3_Cl_Cl',
#     'APC2D3_F_X',
#     'APC2D6_C_X',
#     'APC2D6_C_Cl',
#     'APC2D7_C_Cl',
#     'APC2D7_C_X'],
#    'Component 40': ['KRFPC189',
#     'SubFPC48',
#     'APC2D6_O_O',
#     'KRFPC3408',
#     'APC2D1_O_S',
#     'KRFPC1146',
#     'KRFPC3436',
#     'KRFPC1564',
#     'SubFPC88',
#     'KRFPC138'],
#    'Component 41': ['APC2D1_O_P',
#     'APC2D2_C_P',
#     'APC2D3_C_O',
#     'APC2D2_O_O',
#     'APC2D6_C_N',
#     'KRFPC189',
#     'APC2D3_C_P',
#     'SubFPC246',
#     'APC2D3_C_S',
#     'SubFPC48'],
#    'Component 42': ['KRFPC4331',
#     'APC2D3_C_S',
#     'KRFPC189',
#     'SubFPC48',
#     'APC2D1_O_Si',
#     'APC2D4_C_S',
#     'APC2D2_C_N',
#     'KRFPC3750',
#     'KRFPC1146',
#     'KRFPC3682'],
#    'Component 43': ['APC2D6_O_O',
#     'KRFPC3574',
#     'KRFPC3528',
#     'SubFPC169',
#     'KRFPC3706',
#     'SubFPC88',
#     'KRFPC3058',
#     'APC2D4_O_O',
#     'KRFPC189',
#     'KRFPC444'],
#    'Component 44': ['SubFPC133',
#     'KRFPC2977',
#     'KRFPC1153',
#     'KRFPC4331',
#     'KRFPC3773',
#     'APC2D5_O_O',
#     'KRFPC4080',
#     'SubFPC288',
#     'KRFPC3408',
#     'KRFPC3740'],
#    'Component 45': ['KRFPC3682',
#     'KRFPC3382',
#     'KRFPC3706',
#     'APC2D6_O_O',
#     'KRFPC3610',
#     'KRFPC3159',
#     'APC2D6_C_N',
#     'SubFPC182',
#     'APC2D7_C_N',
#     'APC2D1_C_O']}},
#  'metric': {'similarity_matrix': array([[ 1.00000000e+00,  6.53249681e-01,  9.93539940e-01, ...,
#            1.94039738e-02, -1.63667914e-03, -9.47978812e-03],
#          [ 6.53249681e-01,  1.00000000e+00,  6.63110198e-01, ...,
#            1.57678182e-02,  2.64301494e-03,  5.06305061e-03],
#          [ 9.93539940e-01,  6.63110198e-01,  1.00000000e+00, ...,
#            2.19508592e-02, -5.46502848e-04, -5.71912731e-03],
#          ...,
#          [ 1.94039738e-02,  1.57678182e-02,  2.19508592e-02, ...,
#            1.00000000e+00,  4.63939584e-01, -6.65204338e-03],
#          [-1.63667914e-03,  2.64301494e-03, -5.46502848e-04, ...,
#            4.63939584e-01,  1.00000000e+00,  1.26260768e-02],
#          [-9.47978812e-03,  5.06305061e-03, -5.71912731e-03, ...,
#           -6.65204338e-03,  1.26260768e-02,  1.00000000e+00]]),
#   'pvalue_matrix': array([[0.076, 0.017, 0.002, ..., 1.001, 1.001, 1.001],
#          [0.017, 0.955, 0.026, ..., 1.001, 1.001, 1.001],
#          [0.002, 0.026, 0.435, ..., 1.001, 1.001, 1.001],
#          ...,
#          [1.001, 1.001, 1.001, ..., 0.973, 1.001, 1.001],
#          [1.001, 1.001, 1.001, ..., 1.001, 0.203, 1.001],
#          [1.001, 1.001, 1.001, ..., 1.001, 1.001, 0.59 ]])},
#  'net': {'network':          Source  Target  Similarity  Pvalue  -Log10Pvalue
#   1          8680   10870    0.993540   0.002       2.69897
#   2          8680   69848    0.939722   0.002       2.69897
#   35         8680    8404    0.954820   0.002       2.69897
#   36         8680   10263    0.897342   0.002       2.69897
#   38         8680   10695    0.892842   0.002       2.69897
#   ...         ...     ...         ...     ...           ...
#   1530337    1117   26042    0.612644   0.002       2.69897
#   1530339    1119   24682    0.992558   0.002       2.69897
#   1530352   24682   26042    0.607303   0.002       2.69897
#   1530363   14778   26042    0.950849   0.002       2.69897
#   1530369   14781   11430    0.774117   0.002       2.69897
#
#   [326949 rows x 5 columns],
#   'graph': <networkx.classes.graph.Graph at 0x1986c1ca200>}}

# %%
# get fingerprints counts by subsetting preprocessed columns 
fingerprint_counts = fingerprint_data.loc[:, Fpc_obj['annotation']['features']]
fingerprint_counts.columns
# Out:
# Index(['SubFPC1', 'SubFPC2', 'SubFPC3', 'SubFPC4', 'SubFPC5', 'SubFPC6',
#        'SubFPC7', 'SubFPC8', 'SubFPC9', 'SubFPC10',
#        ...
#        'APC2D10_C_X', 'APC2D10_N_N', 'APC2D10_O_O', 'APC2D10_O_F',
#        'APC2D10_O_X', 'APC2D10_Cl_Cl', 'APC2D10_Cl_X', 'APC2D10_Br_Br',
#        'APC2D10_Br_X', 'APC2D10_X_X'],
#       dtype='object', length=1515)

# %%
# print idf values of fingeprints counts
df_idf_fpc = pd.DataFrame(Fpc_obj['tfidf']['tfidf_transformer'].idf_, index=fingerprint_counts.columns, columns=["idf_weights"]) 
# sort ascending 
df_idf_fpc.sort_values(by=['idf_weights'])
# Out:
#             idf_weights
# SubFPC307      1.013222
# APC2D1_C_C     1.055782
# APC2D2_C_C     1.071607
# KRFPC2975      1.111662
# SubFPC300      1.121287
# ...                 ...
# KRFPC4258      7.774795
# KRFPC4257      7.774795
# KRFPC1759      7.774795
# KRFPC4328      7.774795
# KRFPC3362      7.774795
#
# [1515 rows x 1 columns]

# %% [markdown]
# ##### FP counts classes:
# | Fingerprint | Class | Number | Code |
# | --- | --- | --- | --- |
# | Substructure fingerprint count | SubstructureFingerprintCount | 307 | SubFPC
# | Klekota-Roth fingerprint count | KlekotaRothFingerprintCount | 4860 | KRFPC
# | 2D atom pairs count | AtomPairs2DFingerprintCount | 780 | APC2D

# %%
# subset fingerprints bits classes
fpc_classes = ['SubFPC', 'KRFPC', 'APC2D']

# %%
# get idf weights of fingerprints bits classes 
fpc_classes_df = pd.DataFrame()
for i in fpc_classes:
    df = df_idf_fpc[df_idf_fpc.index.str.startswith(i)]
    df.insert(0, 'Fingerprint', df.index)
    df.insert(2, 'Class', i)
    # sort weights
    df = df.sort_values(by=['idf_weights'])
    fpc_classes_df = pd.concat([fpc_classes_df, df])
fpc_classes_df
# Out:
#                Fingerprint  idf_weights   Class
# SubFPC307        SubFPC307     1.013222  SubFPC
# SubFPC301        SubFPC301     1.121287  SubFPC
# SubFPC300        SubFPC300     1.121287  SubFPC
# SubFPC302        SubFPC302     1.333051  SubFPC
# SubFPC1            SubFPC1     1.400622  SubFPC
# ...                    ...          ...     ...
# APC2D6_Br_X    APC2D6_Br_X     7.774795   APC2D
# APC2D6_Br_Br  APC2D6_Br_Br     7.774795   APC2D
# APC2D4_O_F      APC2D4_O_F     7.774795   APC2D
# APC2D7_O_Si    APC2D7_O_Si     7.774795   APC2D
# APC2D7_O_Br    APC2D7_O_Br     7.774795   APC2D
#
# [1515 rows x 3 columns]

# %%
# plot the fingerprints counts distribution
fig = px.line_polar(fpc_classes_df, r='idf_weights', theta='Fingerprint', 
                    width=425, height=400, line_close=False, color='Class', title="Fingerprints Counts - Weights Distribution (IDF)",
                    color_discrete_sequence=px.colors.sequential.Plasma_r, )
# configuration
config = {'modeBarButtonsToRemove': ['zoom'],'displaylogo': False}
fig.update_polars(angularaxis_showticklabels=False)
fig.update_layout(font_size=12, title_x=0.5, title_font_size=14)
# save figure
fig.write_html(path_save + '/fingerprints_counts_idf.html', config=config)
fig.show(config=config)

# %% [markdown]
# #### Molecular descriptors

# %%
# load molecular descriptors data
molecular_descriptors = pd.read_csv(path_read + '/MolecularDescriptorsTable.csv', low_memory=False).astype('float64')
print(molecular_descriptors.index, "\n", molecular_descriptors.columns, "\n")
# Out:
# Int64Index([  8680, 143127,  10870,  69848,  12993, 164514,  86240,  13129,
#              67884,   6278,
#             ...
#              26042,  24193,  23963,  23964,  23989,  23990,  23992,  23993,
#              23994,  23995],
#            dtype='int64', length=1826)
#  Index(['nAcid', 'ALogP', 'ALogp2', 'AMR', 'apol', 'naAromAtom', 'nAromBond',
#        'nAtom', 'nHeavyAtom', 'nH',
#        ...
#        'P1s', 'P2s', 'E1s', 'E2s', 'E3s', 'Ts', 'As', 'Vs', 'Ks', 'Ds'],
#       dtype='object', length=1875)

# %%
# read MD object
filename = '../Preprocessed_data/mol_desc.obj'
filehandler = open(filename, 'rb') 
Md_obj = pickle.load(filehandler)
Md_obj
# Out:
# {'annotation': {'samples': Int64Index([   8680,  143127,   10870,   69848,   12993,  164514,   86240,
#                 13129,   67884,    6278,
#               ...
#                  1117,    1119,   24682, 4685067,   14778,   24841,   14781,
#                 11430,   26042,   24193],
#              dtype='int64', length=1750),
#   'features': Index(['nAcid', 'ALogP', 'ALogp2', 'AMR', 'apol', 'naAromAtom', 'nAromBond',
#          'nAtom', 'nHeavyAtom', 'nH',
#          ...
#          'P1s', 'P2s', 'E1s', 'E2s', 'E3s', 'Ts', 'As', 'Vs', 'Ks', 'Ds'],
#         dtype='object', length=1675)},
#  'pca': {'pca_data': array([[ -7.05043105,   4.41111069,  -8.69597704, ...,   1.06360682,
#             1.51658494,   0.22010407],
#          [  0.58941326,  -2.41669609, -11.55908192, ...,  -0.17072875,
#            -0.07989102,  -0.16213433],
#          [ -6.67228085,   3.56642181,  -8.64308698, ...,   0.13109836,
#             1.18292608,   0.89302626],
#          ...,
#          [ -9.13388871,  -6.88906247,  15.71301314, ...,   2.7809437 ,
#           -12.46116213,   2.50268253],
#          [-10.57732586, -10.07378524,  13.79297579, ...,  -0.69309924,
#            -0.99418702,   1.50133681],
#          [ -8.18244744,  -8.02926647,  15.09438398, ...,   4.56407884,
#             1.8651216 ,  -9.48635407]]),
#   'features_components': {'Component 0': ['Sv',
#     'McGowan_Volume',
#     'VABC',
#     'ATS1e',
#     'ATS1v',
#     'ATS0e',
#     'Spe',
#     'ATS1p',
#     'nBonds2',
#     'Sare'],
#    'Component 1': ['MLFER_E',
#     'SpMax1_Bhe',
#     'TpiPC',
#     'ETA_Eta_F_L',
#     'ETA_Beta_ns',
#     'MIC4',
#     'MIC5',
#     'ETA_Eta_F',
#     'SpMax1_Bhv',
#     'nBondsD'],
#    'Component 2': ['Mpe',
#     'AATS0e',
#     'Mse',
#     'Mare',
#     'TDB1e',
#     'ETA_dEpsilon_A',
#     'ETA_Epsilon_1',
#     'WTPT.3',
#     'SM1_Dzi',
#     'MIC0'],
#    'Component 3': ['nssssC',
#     'VC.3',
#     'MDEC.34',
#     'MDEC.24',
#     'C4SP3',
#     'SC.4',
#     'SC.3',
#     'VPC.4',
#     'GGI1',
#     'MDEC.14'],
#    'Component 4': ['SM1_Dzv',
#     'SM1_Dzp',
#     'BCUTp.1l',
#     'TDB1p',
#     'gmin',
#     'RHSA',
#     'TDB2p',
#     'minwHBa',
#     'TDB1v',
#     'TDB1r'],
#    'Component 5': ['TDB8p',
#     'AATS8p',
#     'TDB8r',
#     'TDB7p',
#     'P1v',
#     'P1p',
#     'TDB8e',
#     'TDB8v',
#     'TDB7v',
#     'TDB7r'],
#    'Component 6': ['SM1_Dzm',
#     'SM1_DzZ',
#     'GATS3c',
#     'AATS4m',
#     'nX',
#     'nsCl',
#     'TDB4m',
#     'nCl',
#     'SsCl',
#     'AATS5m'],
#    'Component 7': ['AATSC2e',
#     'AATSC2i',
#     'ATSC0p',
#     'ATS0p',
#     'SpMin5_Bhp',
#     'topoShape',
#     'topoDiameter',
#     'topoRadius',
#     'ATSC2p',
#     'AATSC2v'],
#    'Component 8': ['ATSC0p',
#     'ATS0p',
#     'AATSC2e',
#     'AATSC0p',
#     'AATSC0v',
#     'AATS0p',
#     'Mp',
#     'ATSC2p',
#     'AATSC2i',
#     'topoRadius'],
#    'Component 9': ['nHBDon',
#     'nHBd',
#     'SHBd',
#     'nHsOH',
#     'nsOH',
#     'SsOH',
#     'SHsOH',
#     'nHBDon_Lipinski',
#     'maxHBd',
#     'minHBd'],
#    'Component 10': ['E2p',
#     'E2s',
#     'Ds',
#     'E3m',
#     'E3p',
#     'Dp',
#     'E3i',
#     'Di',
#     'E3e',
#     'FPSA.3'],
#    'Component 11': ['Ds',
#     'E3m',
#     'E3p',
#     'Dp',
#     'E3i',
#     'Di',
#     'E3e',
#     'E2p',
#     'E2s',
#     'FPSA.3'],
#    'Component 12': ['VE1_Dzm',
#     'VE1_DzZ',
#     'MDEO.22',
#     'nssssSi',
#     'ATSC8p',
#     'SpMax1_Bhm',
#     'SssO',
#     'nssO',
#     'AVP.1',
#     'ATSC8i'],
#    'Component 13': ['nsF',
#     'nF',
#     'SsF',
#     'MATS8m',
#     'MATS8e',
#     'TDB3s',
#     'AATS3s',
#     'AATSC8v',
#     'MATS8v',
#     'MATS8s'],
#    'Component 14': ['MATS5e',
#     'AATSC5e',
#     'GATS4c',
#     'MATS5c',
#     'GATS4s',
#     'ATSC5e',
#     'MATS5s',
#     'AATSC5c',
#     'MATS5m',
#     'ATSC5m'],
#    'Component 15': ['MATS4m',
#     'GATS5c',
#     'SsOH',
#     'ATSC4m',
#     'MATS4c',
#     'MATS4e',
#     'nHsOH',
#     'nsOH',
#     'MATS4s',
#     'maxwHBa'],
#    'Component 16': ['MATS3v',
#     'AATSC3v',
#     'MATS3m',
#     'ATSC3i',
#     'ATSC3v',
#     'MATS3p',
#     'minHtCH',
#     'maxHtCH',
#     'SHtCH',
#     'nHtCH'],
#    'Component 17': ['Ds',
#     'E3m',
#     'E3p',
#     'E3e',
#     'Dp',
#     'E3i',
#     'Di',
#     'E2p',
#     'E2s',
#     'FPSA.3'],
#    'Component 18': ['VR1_Dzp',
#     'VR2_Dzp',
#     'VR1_Dzm',
#     'VR1_DzZ',
#     'VR2_Dzv',
#     'VR1_Dzi',
#     'VR1_Dze',
#     'VR2_Dzi',
#     'VR2_Dze',
#     'VR2_Dzm'],
#    'Component 19': ['ATSC8m',
#     'ATSC8p',
#     'ATSC8v',
#     'ATSC8i',
#     'ATSC3p',
#     'nssssSi',
#     'n10Ring',
#     'n10HeteroRing',
#     'ATSC4e',
#     'AATSC8p'],
#    'Component 20': ['MATS6c',
#     'MATS6s',
#     'MATS6e',
#     'MATS6m',
#     'AATSC6c',
#     'ATSC6c',
#     'AATSC6e',
#     'ATSC6s',
#     'AATSC6s',
#     'ATSC6e'],
#    'Component 21': ['AATS1p',
#     'AATSC0c',
#     'AATSC2c',
#     'BCUTc.1h',
#     'ATSC0c',
#     'ATSC2c',
#     'AATS1m',
#     'AATSC6v',
#     'AATS1v',
#     'MATS6v'],
#    'Component 22': ['SHtCH',
#     'nHtCH',
#     'ntCH',
#     'minHtCH',
#     'maxHtCH',
#     'StCH',
#     'AATSC5v',
#     'mintCH',
#     'maxtCH',
#     'MATS5v'],
#    'Component 23': ['nssO',
#     'SssO',
#     'maxssO',
#     'minssO',
#     'nF12Ring',
#     'nT12Ring',
#     'SaaaC',
#     'nFRing',
#     'nFG12Ring',
#     'nTG12Ring'],
#    'Component 24': ['nHdCH2',
#     'ndCH2',
#     'SdCH2',
#     'maxdCH2',
#     'mindCH2',
#     'maxdsCH',
#     'SHdCH2',
#     'mindsCH',
#     'maxHdCH2',
#     'minHdCH2'],
#    'Component 25': ['AATS1p',
#     'AATSC0c',
#     'BCUTc.1h',
#     'AATSC2c',
#     'ATSC0c',
#     'ATSC2c',
#     'SHsNH3p',
#     'AATS1m',
#     'nHsNH3p',
#     'nsNH3p'],
#    'Component 26': ['nsBr',
#     'nBr',
#     'TDB10m',
#     'SsBr',
#     'RDF110m',
#     'RDF20m',
#     'AATSC0c',
#     'AATS1p',
#     'ATSC0c',
#     'AATSC2c'],
#    'Component 27': ['maxHsssNHp',
#     'SHsssNHp',
#     'minHsssNHp',
#     'nHsssNHp',
#     'nsssNHp',
#     'AATSC0c',
#     'ATSC0c',
#     'AATSC2c',
#     'AATS1p',
#     'BCUTc.1h'],
#    'Component 28': ['nP',
#     'ndsssP',
#     'SaaNH',
#     'minaaNH',
#     'maxaaNH',
#     'nHaaNH',
#     'naaNH',
#     'SHaaNH',
#     'minHaaNH',
#     'maxHaaNH'],
#    'Component 29': ['SHssNH',
#     'nHssNH',
#     'nssNH',
#     'maxHssNH',
#     'minHssNH',
#     'SssNH',
#     'maxssNH',
#     'minssNH',
#     'nHBint2',
#     'SHBint2'],
#    'Component 30': ['SdNH',
#     'mindNH',
#     'maxdNH',
#     'nHdNH',
#     'ndNH',
#     'maxHdNH',
#     'SHdNH',
#     'minHdNH',
#     'AATS3p',
#     'SpMin4_Bhp'],
#    'Component 31': ['ETA_dPsi_B',
#     'nI',
#     'SHCHnX',
#     'mindsN',
#     'maxdsN',
#     'AATSC0m',
#     'maxHCHnX',
#     'AATS3p',
#     'minHCHnX',
#     'SsF'],
#    'Component 32': ['nHsSH',
#     'nsSH',
#     'SHsSH',
#     'minHsSH',
#     'maxHsSH',
#     'SsSH',
#     'minsSH',
#     'maxsSH',
#     'nHaaNH',
#     'naaNH'],
#    'Component 33': ['ECCEN',
#     'AATSC0c',
#     'AATSC2c',
#     'ATSC0c',
#     'ATSC2c',
#     'BCUTc.1h',
#     'nHBint2',
#     'maxHBint2',
#     'SHBint2',
#     'minHsNH2'],
#    'Component 34': ['nHsSH',
#     'nsSH',
#     'minsSH',
#     'maxsSH',
#     'SsSH',
#     'SHsSH',
#     'minHsSH',
#     'maxHsSH',
#     'SssNH',
#     'nHssNH'],
#    'Component 35': ['nHsSH',
#     'nsSH',
#     'SHsSH',
#     'minHsSH',
#     'maxHsSH',
#     'minsSH',
#     'maxsSH',
#     'SsSH',
#     'WPATH',
#     'SpAD_D'],
#    'Component 36': ['VE2_Dt',
#     'ETA_dPsi_B',
#     'VE2_D',
#     'nI',
#     'BCUTw.1l',
#     'nHssNH',
#     'nssNH',
#     'SHssNH',
#     'ETA_Psi_1',
#     'maxHssNH'],
#    'Component 37': ['nHdNH',
#     'ndNH',
#     'SHdNH',
#     'minHdNH',
#     'maxHdNH',
#     'SdNH',
#     'mindNH',
#     'maxdNH',
#     'SaaNH',
#     'minaaNH'],
#    'Component 38': ['E3s',
#     'Du',
#     'E3u',
#     'Dm',
#     'De',
#     'E3v',
#     'Dv',
#     'nsssN',
#     'GATS2c',
#     'SsssN'],
#    'Component 39': ['TDB10m',
#     'nsBr',
#     'nBr',
#     'VCH.3',
#     'SCH.3',
#     'n3Ring',
#     'SRW3',
#     'n3HeteroRing',
#     'AATSC3e',
#     'SsBr'],
#    'Component 40': ['E3s',
#     'E3v',
#     'Dv',
#     'De',
#     'Dm',
#     'E3u',
#     'Du',
#     'nHaaNH',
#     'naaNH',
#     'SaaNH'],
#    'Component 41': ['minHssNH2p',
#     'maxHssNH2p',
#     'SHssNH2p',
#     'minssNH2p',
#     'maxssNH2p',
#     'nHssNH2p',
#     'nssNH2p',
#     'SssNH2p',
#     'TDB6s',
#     'AATS6s'],
#    'Component 42': ['minssNH2p',
#     'maxssNH2p',
#     'minHssNH2p',
#     'maxHssNH2p',
#     'nHssNH2p',
#     'nssNH2p',
#     'SHssNH2p',
#     'nBase',
#     'SssNH2p',
#     'SsssNHp'],
#    'Component 43': ['maxdsN',
#     'mindsN',
#     'ndsN',
#     'SdsN',
#     'SddC',
#     'minddC',
#     'maxddC',
#     'nddC',
#     'MATS3p',
#     'ETA_dPsi_B'],
#    'Component 44': ['maxaaN',
#     'minaaN',
#     'naaN',
#     'SaaN',
#     'n6HeteroRing',
#     'nT6HeteroRing',
#     'AATSC7e',
#     'nF11HeteroRing',
#     'nT11HeteroRing',
#     'nT7HeteroRing'],
#    'Component 45': ['n6HeteroRing',
#     'nT6HeteroRing',
#     'maxaaN',
#     'minaaN',
#     'AATSC8s',
#     'AATSC7e',
#     'MATS8s',
#     'naaN',
#     'ATSC7e',
#     'SaaN'],
#    'Component 46': ['ETA_Psi_1',
#     'AATSC7c',
#     'ETA_dPsi_B',
#     'AATSC7e',
#     'AATSC7s',
#     'minssNH2p',
#     'maxssNH2p',
#     'minHssNH2p',
#     'maxHssNH2p',
#     'SHssNH2p'],
#    'Component 47': ['nF11HeteroRing',
#     'nT11HeteroRing',
#     'ndssS',
#     'nHBint9',
#     'n7HeteroRing',
#     'SHBint9',
#     'n7Ring',
#     'SHBint10',
#     'maxHBint10',
#     'nHBint10']}},
#  'metric': {'similarity_matrix': array([[ 1.        ,  0.42187831,  0.82621539, ..., -0.00463766,
#           -0.10752324, -0.02958409],
#          [ 0.42187831,  1.        ,  0.46306068, ..., -0.04595783,
#           -0.18190826, -0.07270281],
#          [ 0.82621539,  0.46306068,  1.        , ...,  0.00710688,
#           -0.09526436, -0.02890878],
#          ...,
#          [-0.00463766, -0.04595783,  0.00710688, ...,  1.        ,
#            0.25023664,  0.04482482],
#          [-0.10752324, -0.18190826, -0.09526436, ...,  0.25023664,
#            1.        ,  0.8469218 ],
#          [-0.02958409, -0.07270281, -0.02890878, ...,  0.04482482,
#            0.8469218 ,  1.        ]]),
#   'pvalue_matrix': array([[0.997, 1.001, 0.002, ..., 1.001, 1.001, 1.001],
#          [1.001, 0.806, 1.001, ..., 1.001, 1.001, 1.001],
#          [0.002, 1.001, 0.945, ..., 1.001, 1.001, 1.001],
#          ...,
#          [1.001, 1.001, 1.001, ..., 0.997, 1.001, 1.001],
#          [1.001, 1.001, 1.001, ..., 1.001, 0.536, 0.002],
#          [1.001, 1.001, 1.001, ..., 1.001, 0.002, 0.546]])},
#  'net': {'network':          Source  Target  Similarity  Pvalue  -Log10Pvalue
#   1          8680   10870    0.826215   0.002       2.69897
#   2          8680   69848    0.857324   0.002       2.69897
#   35         8680    8404    0.748868   0.002       2.69897
#   36         8680   10263    0.602239   0.002       2.69897
#   38         8680   10695    0.616637   0.002       2.69897
#   ...         ...     ...         ...     ...           ...
#   1530352   24682   26042    0.655614   0.002       2.69897
#   1530360   14778   24841    0.684710   0.002       2.69897
#   1530363   14778   26042    0.902797   0.002       2.69897
#   1530364   14778   24193    0.642958   0.002       2.69897
#   1530374   26042   24193    0.846922   0.002       2.69897
#
#   [85320 rows x 5 columns],
#   'graph': <networkx.classes.graph.Graph at 0x19213cb9a80>}}

# %%
# get molecular descriptors by subsetting preprocessed columns and rows
molecular_desc = molecular_descriptors.loc[:, Md_obj['annotation']['features']]
molecular_desc = molecular_desc.loc[Md_obj['annotation']['samples'],:]
molecular_desc.columns
# Out:
# Index(['nAcid', 'ALogP', 'ALogp2', 'AMR', 'apol', 'naAromAtom', 'nAromBond',
#        'nAtom', 'nHeavyAtom', 'nH',
#        ...
#        'P1s', 'P2s', 'E1s', 'E2s', 'E3s', 'Ts', 'As', 'Vs', 'Ks', 'Ds'],
#       dtype='object', length=1675)

# %%
# load molecules table 
molecules = pd.read_csv(path_read + '/MoleculesTable.csv', encoding='latin1')
molecules.head()
# Out:
#                 Chemical_Name     CID         CAS  \
# 0     (1-methylpropyl)benzene    8680    135-98-8
# 1  (2-methylbutyl)cyclohexane  143127  54105-77-0
# 2     (2-methylpropyl)benzene   10870    538-93-2
# 3       1,1,1-trichloroethane    6278     71-55-6
# 4   1,1,2,2-tetrachloroethane    6591     79-34-5
#
#                       InChIKey   Canonical_SMILES Molecular_Formula    Atoms  \
# 0  ZJMWRROPUADPEA-UHFFFAOYSA-N  CCC(C)C1=CC=CC=C1            C10H14      [C]
# 1  DDQXBDLAGHZBMP-UHFFFAOYSA-N    CCC(C)CC1CCCCC1            C11H22      [C]
# 2  KXUHSQYYJYAXGZ-UHFFFAOYSA-N  CC(C)CC1=CC=CC=C1            C10H14      [C]
# 3  UOCLXMDMGBRAIB-UHFFFAOYSA-N       CC(Cl)(Cl)Cl           C2H3Cl3  [C, Cl]
# 4  QPFMBZIOSGYJDE-UHFFFAOYSA-N   C(C(Cl)Cl)(Cl)Cl           C2H2Cl4  [C, Cl]
#
#   Molecule_Type
# 0       organic
# 1       organic
# 2       organic
# 3       organic
# 4       organic

# %%
# take CID, Molecular Formula and Molecule Type to represent molecules in PCA plot
col = molecules[['CID', 'Molecular_Formula', 'Molecule_Type']][molecules.CID.isin(molecular_desc.index)]
col['CID'] = pd.Categorical(col.CID, ordered=True, categories=molecular_desc.index)
col.sort_values('CID', inplace=True)
col
# Out:
#          CID Molecular_Formula Molecule_Type
# 0       8680            C10H14       organic
# 1     143127            C11H22       organic
# 2      10870            C10H14       organic
# 1641   69848            C10H12       organic
# 1651   12993             C5H8O       organic
# ...      ...               ...           ...
# 1024   24841                HI     inorganic
# 921    14781         Ca5HO13P3     inorganic
# 1476   11430             CK2O3     inorganic
# 1481   26042              O2Ti     inorganic
# 1808   24193             Cl4Ti     inorganic
#
# [1750 rows x 3 columns]

# %%
# set hover text 
cid_formula = [('CID: '+str(x[0]), " Formula: "+x[1]) for x in col.values]
cid_formula[0:10]
# Out:
# [('CID: 8680', ' Formula: C10H14'),
#  ('CID: 143127', ' Formula: C11H22'),
#  ('CID: 10870', ' Formula: C10H14'),
#  ('CID: 69848', ' Formula: C10H12'),
#  ('CID: 12993', ' Formula: C5H8O'),
#  ('CID: 164514', ' Formula: C5H3F9O'),
#  ('CID: 86240', ' Formula: C5H2F10'),
#  ('CID: 13129', ' Formula: C2H2F4'),
#  ('CID: 67884', ' Formula: C4H5F5'),
#  ('CID: 6278', ' Formula: C2H3Cl3')]

# %%
# plot first 5 components of PCA 
n_components = 5 
labels = {str(i): f"PC {i+1}" for i in range(n_components)}
# set color
color = col.Molecule_Type
labels['color'] = 'Molecule type'

fig = px.scatter_matrix(
    Md_obj['pca']['pca_data'],
    width=480, height=430,
    dimensions=range(n_components),
    color=color,
    labels=labels,
    hover_name=cid_formula,   
    title="Molecular Descriptors - Explained Variance (PCA)"
)

# remove diagonal 
fig.update_traces(diagonal_visible=False)
fig.update_layout(font_size=12, title_x=0.5, title_font_size=14)

# remove x and y ticks
fig.update_layout({"xaxis"+str(i+1): dict(showticklabels=False) for i in range(n_components)})
fig.update_layout({"yaxis"+str(i+1): dict(showticklabels=False) for i in range(n_components)})
fig.update_layout(legend=dict(orientation="h", y=-0.2))

# cofiguration
config = {'modeBarButtonsToRemove': ['logo', 'zoom', 'pan',
          'select', 'lasso', 'autoscale'], 'displaylogo': False}

# save figure
fig.write_html(path_save + '/molecular_descriptors_PCA.html', config=config)
fig.show(config=config)

# %% [markdown]
# #### Quantum properties

# %%
# load quantum properties data
quantum_properties = pd.read_csv(path_read + '/QuantumPropertiesTable.csv')
quantum_properties = quantum_properties.set_index('Molecule_CID')
quantum_properties.index
# Out:
# Int64Index([528971,  13387,   7304,   7903, 181154,   8247,   5897,  79123,
#               7245, 182210,
#             ...
#              26042,  24193,  23963,  23964,  23989,  23990,  23992,  23993,
#              23994,  23995],
#            dtype='int64', name='Molecule_CID', length=1826)

# %%
# read QP object
filename = '../Preprocessed_data/quantum_props.obj'
filehandler = open(filename, 'rb') 
Qp_obj = pickle.load(filehandler)
Qp_obj
# Out:
# {'annotation': {'samples': Int64Index([ 528971,   13387,    7304,    7903,  181154,    8247,    5897,
#                 79123,    7245,  182210,
#               ...
#                 24682, 4685067,   14781,   14778,   25477,   24841,    6328,
#                 11430,   26042,   24193],
#              dtype='int64', name='Molecule_CID', length=1750),
#   'features': Index(['Gas_Phase_Energy', 'Final_Energy', 'HOMO', 'LUMO', 'Polarizability',
#          'QM_Dipole', 'QM_Dipole_X', 'QM_Dipole_Y', 'QM_Dipole_Z',
#          'Lowest_Frequency', 'Highest_Frequency', 'Second_Lowest_Frequency',
#          'Num_Negative_Frequencies', 'Zero_Point_Energy', 'Entropy', 'Enthalpy',
#          'Free_Energy', 'Internal_Energy', 'Heat_Capacity', 'ln_Q',
#          'Total_Internal_Energy', 'Total_Enthalpy', 'Total_Free_Energy'],
#         dtype='object')},
#  'pca': {'pca_data': array([[ 6.83221008, -2.03569661, -2.53132431, ..., -0.50173662,
#            0.04728384,  0.28558018],
#          [-2.44563902,  0.07856449,  0.18794303, ..., -0.47827785,
#            0.0644584 ,  0.21980293],
#          [-2.81588424, -0.05129354,  0.88149749, ..., -0.27477591,
#            0.03169385, -0.0619461 ],
#          ...,
#          [-1.58831773,  2.38965327,  2.40081468, ...,  0.5396364 ,
#           -0.03170596,  4.77583736],
#          [-2.60074111,  1.8563259 ,  2.50353268, ...,  3.96000315,
#           -0.83025761, -7.13903272],
#          [-0.56960889,  4.6074973 , -0.96677031, ...,  1.31130861,
#           -0.33775727,  3.60503936]]),
#   'features_components': {'Component 0': ['ln_Q',
#     'Entropy',
#     'Enthalpy',
#     'Internal_Energy',
#     'Heat_Capacity',
#     'Polarizability',
#     'Zero_Point_Energy',
#     'QM_Dipole',
#     'QM_Dipole_Y',
#     'HOMO'],
#    'Component 1': ['Num_Negative_Frequencies',
#     'Free_Energy',
#     'QM_Dipole_X',
#     'QM_Dipole_Z',
#     'HOMO',
#     'Highest_Frequency',
#     'Polarizability',
#     'Second_Lowest_Frequency',
#     'QM_Dipole_Y',
#     'LUMO'],
#    'Component 2': ['HOMO',
#     'QM_Dipole',
#     'LUMO',
#     'QM_Dipole_Y',
#     'Num_Negative_Frequencies',
#     'Free_Energy',
#     'Highest_Frequency',
#     'Final_Energy',
#     'Gas_Phase_Energy',
#     'Total_Free_Energy'],
#    'Component 3': ['Highest_Frequency',
#     'Num_Negative_Frequencies',
#     'QM_Dipole_X',
#     'Total_Internal_Energy',
#     'Total_Enthalpy',
#     'Total_Free_Energy',
#     'Gas_Phase_Energy',
#     'Final_Energy',
#     'Polarizability',
#     'QM_Dipole_Z'],
#    'Component 4': ['QM_Dipole_Y',
#     'QM_Dipole',
#     'Num_Negative_Frequencies',
#     'Highest_Frequency',
#     'Free_Energy',
#     'Total_Free_Energy',
#     'Total_Enthalpy',
#     'Total_Internal_Energy',
#     'Final_Energy',
#     'Gas_Phase_Energy'],
#    'Component 5': ['QM_Dipole_X',
#     'LUMO',
#     'HOMO',
#     'QM_Dipole_Y',
#     'Heat_Capacity',
#     'Zero_Point_Energy',
#     'Enthalpy',
#     'Internal_Energy',
#     'Free_Energy',
#     'Entropy'],
#    'Component 6': ['Num_Negative_Frequencies',
#     'Polarizability',
#     'Total_Enthalpy',
#     'Total_Internal_Energy',
#     'Total_Free_Energy',
#     'Final_Energy',
#     'Gas_Phase_Energy',
#     'Zero_Point_Energy',
#     'HOMO',
#     'Lowest_Frequency']}},
#  'metric': {'similarity_matrix': array([[ 1.        , -0.8944739 , -0.94450006, ..., -0.32331201,
#           -0.22615107, -0.22158998],
#          [-0.8944739 ,  1.        ,  0.96293005, ...,  0.25294294,
#            0.06495392,  0.11188261],
#          [-0.94450006,  0.96293005,  1.        , ...,  0.23289653,
#            0.14752546,  0.00902131],
#          ...,
#          [-0.32331201,  0.25294294,  0.23289653, ...,  1.        ,
#            0.40452509,  0.29265658],
#          [-0.22615107,  0.06495392,  0.14752546, ...,  0.40452509,
#            1.        , -0.42240973],
#          [-0.22158998,  0.11188261,  0.00902131, ...,  0.29265658,
#           -0.42240973,  1.        ]]),
#   'pvalue_matrix': array([[1.001, 1.001, 1.001, ..., 1.001, 1.001, 1.001],
#          [1.001, 0.967, 0.008, ..., 1.001, 1.001, 1.001],
#          [1.001, 0.008, 0.518, ..., 1.001, 1.001, 1.001],
#          ...,
#          [1.001, 1.001, 1.001, ..., 0.719, 1.001, 1.001],
#          [1.001, 1.001, 1.001, ..., 1.001, 1.001, 1.001],
#          [1.001, 1.001, 1.001, ..., 1.001, 1.001, 1.001]])},
#  'net': {'network':          Source    Target  Similarity  Pvalue  -Log10Pvalue
#   3        528971    181154    0.994300   0.002      2.698970
#   9        528971     94310    0.903952   0.005      2.301030
#   13       528971    176293    0.978215   0.007      2.154902
#   26       528971  12303119    0.996702   0.002      2.698970
#   30       528971     23284    0.974290   0.003      2.522879
#   ...         ...       ...         ...     ...           ...
#   1530290   24261     14778    0.879930   0.009      2.045757
#   1530302   10340     14778    0.841126   0.008      2.096910
#   1530327    1119     11430    0.869260   0.006      2.221849
#   1530348   14781     25477    0.991341   0.002      2.698970
#   1530355   14778     24841    0.828287   0.002      2.698970
#
#   [89893 rows x 5 columns],
#   'graph': <networkx.classes.graph.Graph at 0x19222eaba90>}}

# %%
# get quantum properties by subsetting preprocessed columns and rows
quantum_props = quantum_properties.loc[:, Qp_obj['annotation']['features']]
quantum_props = quantum_props.loc[Qp_obj['annotation']['samples'],:]
quantum_props.columns
# Out:
# Index(['Gas_Phase_Energy', 'Final_Energy', 'HOMO', 'LUMO', 'Polarizability',
#        'QM_Dipole', 'QM_Dipole_X', 'QM_Dipole_Y', 'QM_Dipole_Z',
#        'Lowest_Frequency', 'Highest_Frequency', 'Second_Lowest_Frequency',
#        'Num_Negative_Frequencies', 'Zero_Point_Energy', 'Entropy', 'Enthalpy',
#        'Free_Energy', 'Internal_Energy', 'Heat_Capacity', 'ln_Q',
#        'Total_Internal_Energy', 'Total_Enthalpy', 'Total_Free_Energy'],
#       dtype='object')

# %%
# take CID, Molecular Formula and Molecule Type to represent molecules in PCA plot
col = molecules[['CID', 'Molecular_Formula', 'Molecule_Type']][molecules.CID.isin(quantum_props.index)]
col['CID'] = pd.Categorical(col.CID, ordered=True, categories=quantum_props.index)
col.sort_values('CID', inplace=True)
col
# Out:
#          CID Molecular_Formula Molecule_Type
# 1201  528971            C27H54       organic
# 76     13387            C5H9NO       organic
# 1623    7304             C5H7N       organic
# 1031    7903           C3H7NO2       organic
# 1197  181154            C23H46       organic
# ...      ...               ...           ...
# 1024   24841                HI     inorganic
# 1321    6328              CH3I       organic
# 1476   11430             CK2O3     inorganic
# 1481   26042              O2Ti     inorganic
# 1808   24193             Cl4Ti     inorganic
#
# [1750 rows x 3 columns]

# %%
# set hover text 
cid_formula = [('CID: '+str(x[0]), " Formula: "+x[1]) for x in col.values]
cid_formula[0:10]
# Out:
# [('CID: 528971', ' Formula: C27H54'),
#  ('CID: 13387', ' Formula: C5H9NO'),
#  ('CID: 7304', ' Formula: C5H7N'),
#  ('CID: 7903', ' Formula: C3H7NO2'),
#  ('CID: 181154', ' Formula: C23H46'),
#  ('CID: 8247', ' Formula: C8H10N2O'),
#  ('CID: 5897', ' Formula: C15H13NO'),
#  ('CID: 79123', ' Formula: C4H9NO3'),
#  ('CID: 7245', ' Formula: C6H5ClO'),
#  ('CID: 182210', ' Formula: C20H24O5')]

# %%
# plot first 5 components of PCA 
n_components = 5 
labels = {str(i): f"PC {i+1}" for i in range(n_components)}
# set color
color = col.Molecule_Type
labels['color'] = 'Molecule type'

fig = px.scatter_matrix(
    Qp_obj['pca']['pca_data'],
    width=480, height=430,
    dimensions=range(n_components),
    color=color,
    labels=labels,
    hover_name=cid_formula,   
    title="Quantum Properties - Explained Variance (PCA)"
)

# remove diagonal 
fig.update_traces(diagonal_visible=False)
fig.update_layout(font_size=12, title_x=0.5, title_font_size=14)

# remove x and y ticks
fig.update_layout({"xaxis"+str(i+1): dict(showticklabels=False) for i in range(n_components)})
fig.update_layout({"yaxis"+str(i+1): dict(showticklabels=False) for i in range(n_components)})
fig.update_layout(legend=dict(orientation="h", y=-0.2))

# cofiguration
config = {'modeBarButtonsToRemove': ['logo', 'zoom', 'pan',
          'select', 'lasso', 'autoscale'], 'displaylogo': False}

# save figure
fig.write_html(path_save + '/quantum_properties_PCA.html', config=config)
fig.show(config=config)
